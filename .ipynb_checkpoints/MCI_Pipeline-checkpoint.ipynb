# %%
import pandas as pd
import seaborn as sns
import numpy as np
import xgboost
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
file_list = ["vascular_multimodal_dataset_{}.csv".format(i) for i in range(1, 9)]

# %%
file_list
# Out:
# ['vascular_multimodal_dataset_1.csv',
#  'vascular_multimodal_dataset_2.csv',
#  'vascular_multimodal_dataset_3.csv',
#  'vascular_multimodal_dataset_4.csv',
#  'vascular_multimodal_dataset_5.csv',
#  'vascular_multimodal_dataset_6.csv',
#  'vascular_multimodal_dataset_7.csv',
#  'vascular_multimodal_dataset_8.csv']

# %%
def calculate_vif_(X, thresh=100):
    cols = X.columns
    variables = np.arange(X.shape[1])
    dropped=True
    while dropped:
        dropped=False
        c = X[cols[variables]].values
        vif = [variance_inflation_factor(c, ix) for ix in np.arange(c.shape[1])]

        maxloc = vif.index(max(vif))
        if max(vif) > thresh:
            print('dropping \'' + X[cols[variables]].columns[maxloc] + '\' at index: ' + str(maxloc))
            variables = np.delete(variables, maxloc)
            dropped=True

    print('Remaining variables:')
    print(X.columns[variables])
    return X[cols[variables]]

def buildModel(Y, MCI_df):

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

def doAnalysis(file):
    print("Analysing Dataset: {}".format(file))
    df = pd.read_csv(file)
    sns.heatmap(df.corr(), cmap='coolwarm')
    Y = df['PO_PR_RAVLT_1.5_SUM']
    MCI_df = calculate_vif_(df)
    MCI_df['PO_PR_RAVLT_1.5_SUM'] = Y
    
    #plotting the correlation of the feature variables with the target variable
    sns.pairplot(MCI_df, x_vars=MCI_df.columns[:-1], y_vars = ['PO_PR_RAVLT_1.5_SUM'], kind="reg", height=4)
    
    MCI_df.drop('PO_PR_RAVLT_1.5_SUM', axis=1)
    model = buildModel(Y, MCI_df)
    
    

models = []
for file in file_list:
    models.append(doAnalysis(file))
# Out:
# Analysing Dataset: vascular_multimodal_dataset_1.csv
# e:\programs\python36\lib\site-packages\statsmodels\stats\outliers_influence.py:181: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# dropping 'PO_PR_RAVLT_1.5_SUM' at index: 1
# dropping 'left_fimbria_volume_PR' at index: 1
# dropping 'left_Hippo_Tail_volume_PR' at index: 1
# dropping 'left_subiculum_volume_PR' at index: 1
# dropping 'left_presubiculum_volume_PR' at index: 1
# dropping 'left_CA4_DG_volume_PR' at index: 1
# dropping 'left_CA1_volume_PR' at index: 1
# dropping 'left_hippocampal_fissure_volume_PR' at index: 1
# dropping 'left_CA2_3_volume_PR' at index: 1
# dropping 'right_fimbria_volume_PR' at index: 1
# dropping 'right_Hippo_Tail_volume_PR' at index: 1
# dropping 'right_subiculum_volume_PR' at index: 1
# dropping 'right_presubiculum_volume_PR' at index: 1
# dropping 'right_CA4_DG_volume_PR' at index: 1
# dropping 'right_CA1_volume_PR' at index: 1
# dropping 'right_hippocampal_fissure_volume_PR' at index: 1
# dropping 'right_CA2_3_volume_PR' at index: 1
# dropping 'lh_bankssts_volume_PR' at index: 1
# dropping 'lh_caudalanteriorcingulate_volume_PR' at index: 1
# dropping 'lh_caudalmiddlefrontal_volume_PR' at index: 1
# dropping 'lh_cuneus_volume_PR' at index: 1
# dropping 'lh_entorhinal_volume_PR' at index: 1
# dropping 'lh_fusiform_volume_PR' at index: 1
# dropping 'lh_inferiorparietal_volume_PR' at index: 1
# dropping 'lh_inferiortemporal_volume_PR' at index: 1
# dropping 'lh_isthmuscingulate_volume_PR' at index: 1
# dropping 'lh_lateraloccipital_volume_PR' at index: 1
# dropping 'lh_lateralorbitofrontal_volume_PR' at index: 1
# dropping 'lh_lingual_volume_PR' at index: 1
# dropping 'lh_medialorbitofrontal_volume_PR' at index: 1
# dropping 'lh_middletemporal_volume_PR' at index: 1
# dropping 'lh_parahippocampal_volume_PR' at index: 1
# dropping 'lh_paracentral_volume_PR' at index: 1
# dropping 'lh_parsopercularis_volume_PR' at index: 1
# dropping 'lh_parsorbitalis_volume_PR' at index: 1
# dropping 'lh_parstriangularis_volume_PR' at index: 1
# dropping 'lh_pericalcarine_volume_PR' at index: 1
# dropping 'lh_postcentral_volume_PR' at index: 1
# dropping 'lh_posteriorcingulate_volume_PR' at index: 1
# dropping 'lh_precentral_volume_PR' at index: 1
# dropping 'lh_precuneus_volume_PR' at index: 1
# dropping 'PO_PR_ASL_Hippo_UNAFF' at index: 9
# Remaining variables:
# Index(['PID', 'lh_rostralanteriorcingulate_volume_PR',
#        '1000*N_PO_PR_AFF_Total_Hippo', '1000*N_PO_PR_UNAFF_Total_Hippo',
#        'PO_PR_AFF_FA_CH', 'PO_PR_UNAFF_FA_CH', 'PO_PR_AFF_MD_CH',
#        'PO_PR_UNAFF_MD_CH', 'PO_PR_ASL_Hippo_AFF'],
#       dtype='object')
# e:\programs\python36\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-c799b77769ae> in <module>()
#      21 models = []
#      22 for file in file_list:
# ---> 23     models.append(doAnalysis(file))
#
# <ipython-input-24-c799b77769ae> in doAnalysis(file)
#      15
#      16     MCI_df.drop('PO_PR_RAVLT_1.5_SUM', axis=1)
# ---> 17     model = buildModel(Y, MCI_df)
#      18
#      19
#
# NameError: name 'buildModel' is not defined
